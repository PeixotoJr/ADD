# %% [markdown]
# <a href="https://colab.research.google.com/github/PeixotoJr/ADD/blob/main/Elimina%C3%A7%C3%A3o_Manual_de_Atributos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Eliminação Manual de Atributos

# %%
import pandas as pd
dados = pd.read_csv('breast_cancer.csv',sep=',')

# %%
dados
# Out:
#      sample_id  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0       842302        17.99         10.38          122.80     1001.0
# 1       842517        20.57         17.77          132.90     1326.0
# 2     84300903        19.69         21.25          130.00     1203.0
# 3     84348301        11.42         20.38           77.58      386.1
# 4     84358402        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564     926424        21.56         22.39          142.00     1479.0
# 565     926682        20.13         28.25          131.20     1261.0
# 566     926954        16.60         28.08          108.30      858.1
# 567     927241        20.60         29.33          140.10     1265.0
# 568      92751         7.76         24.54           47.92      181.0
#
#      mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean_symmetry  ...  worst_texture  worst_perimeter  worst_area  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension  diagnosis
# 0                  0.2654          0.4601                  0.11890  malignant
# 1                  0.1860          0.2750                  0.08902  malignant
# 2                  0.2430          0.3613                  0.08758  malignant
# 3                  0.2575          0.6638                  0.17300  malignant
# 4                  0.1625          0.2364                  0.07678  malignant
# ..                    ...             ...                      ...        ...
# 564                0.2216          0.2060                  0.07115  malignant
# 565                0.1628          0.2572                  0.06637  malignant
# 566                0.1418          0.2218                  0.07820  malignant
# 567                0.2650          0.4087                  0.12400  malignant
# 568                0.0000          0.2871                  0.07039     benign
#
# [569 rows x 32 columns]

# %%
#removendo a coluna sample_id,a qual nao eh necessaria
#para realizar o diagnostico
del dados['sample_id']
dados
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean_fractal_dimension  ...  worst_texture  worst_perimeter  worst_area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension  diagnosis
# 0                  0.2654          0.4601                  0.11890  malignant
# 1                  0.1860          0.2750                  0.08902  malignant
# 2                  0.2430          0.3613                  0.08758  malignant
# 3                  0.2575          0.6638                  0.17300  malignant
# 4                  0.1625          0.2364                  0.07678  malignant
# ..                    ...             ...                      ...        ...
# 564                0.2216          0.2060                  0.07115  malignant
# 565                0.1628          0.2572                  0.06637  malignant
# 566                0.1418          0.2218                  0.07820  malignant
# 567                0.2650          0.4087                  0.12400  malignant
# 568                0.0000          0.2871                  0.07039     benign
#
# [569 rows x 31 columns]

# %% [markdown]
# **Amostragem simples**

# %%
import pandas as pd
dados = pd.read_csv('breast_cancer.csv')
# gerando auma mostra aleatória simples com  100 elementos
dados.sample(100)
# Out:
#      sample_id  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 220    8812816       13.650         13.16           87.88      568.9
# 446    9110732       17.750         28.03          117.30      981.6
# 256   88649001       19.550         28.77          133.60     1207.0
# 127     866203       19.000         18.91          123.40     1138.0
# 273    8910996        9.742         15.67           61.50      289.9
# ..         ...          ...           ...             ...        ...
# 164    8712289       23.270         22.04          152.10     1686.0
# 285    8912521       12.580         18.40           79.83      489.0
# 530      91858       11.750         17.56           75.89      422.9
# 326      89524       14.110         12.88           90.03      616.5
# 245     884437       10.480         19.86           66.72      337.7
#
#      mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 220          0.09646           0.08711         0.03888             0.025630
# 446          0.09997           0.13140         0.16980             0.082930
# 256          0.09260           0.20630         0.17840             0.114400
# 127          0.08217           0.08028         0.09271             0.056270
# 273          0.09037           0.04689         0.01103             0.014070
# ..               ...               ...             ...                  ...
# 164          0.08439           0.11450         0.13240             0.097020
# 285          0.08393           0.04216         0.00186             0.002924
# 530          0.10730           0.09713         0.05282             0.044400
# 326          0.09309           0.05306         0.01765             0.027330
# 245          0.10700           0.05971         0.04831             0.030700
#
#      mean_symmetry  ...  worst_texture  worst_perimeter  worst_area  \
# 220         0.1360  ...          16.35            99.71       706.2
# 446         0.1713  ...          38.54           145.40      1437.0
# 256         0.1893  ...          36.27           178.60      1926.0
# 127         0.1946  ...          25.73           148.20      1538.0
# 273         0.2081  ...          20.88            68.09       355.2
# ..             ...  ...            ...              ...         ...
# 164         0.1801  ...          28.22           184.20      2403.0
# 285         0.1697  ...          23.08            85.56       564.1
# 530         0.1598  ...          27.98            88.52       552.3
# 326         0.1373  ...          18.00            98.40       749.9
# 245         0.1737  ...          29.46            73.68       402.8
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 220            0.1311            0.24740         0.175900
# 446            0.1401            0.37620         0.639900
# 256            0.1281            0.53290         0.425100
# 127            0.1021            0.22640         0.320700
# 273            0.1467            0.09370         0.040430
# ..                ...                ...              ...
# 164            0.1228            0.35830         0.394800
# 285            0.1038            0.06624         0.005579
# 530            0.1349            0.18540         0.136600
# 326            0.1281            0.11090         0.053070
# 245            0.1515            0.10260         0.118100
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension  diagnosis
# 220              0.080560          0.2380                  0.08718     benign
# 446              0.197000          0.2972                  0.09075  malignant
# 256              0.194100          0.2818                  0.10050  malignant
# 127              0.121800          0.2841                  0.06541  malignant
# 273              0.051590          0.2841                  0.08175     benign
# ..                    ...             ...                      ...        ...
# 164              0.234600          0.3589                  0.09187  malignant
# 285              0.008772          0.2505                  0.06431     benign
# 530              0.101000          0.2478                  0.07757     benign
# 326              0.058900          0.2100                  0.07083     benign
# 245              0.067360          0.2883                  0.07748     benign
#
# [100 rows x 32 columns]

# %% [markdown]
# **Amostragem Estratificada**

# %%
import pandas as pd
dados = pd.read_csv('breast_cancer.csv')
#tamanho da amostra estratificada
tamanho_amostra=100

#obtendo as classes da base de dados
classes = dados['diagnosis'].unique()

#calculando a quantidade de amostras por classe
#neste exemplo,serao amostradas as mesmas
#quantidades para cada classe
qtde_por_classe = round(tamanho_amostra / len(classes))
amostras_por_classe = []
#nesta lista armazenaremos,para cada classe,um
#pandas.DataFrame com suas amostras
for c in classes:
  #obtendo os indices do DataFrame
  #cujas instancias pertencem a classe c
  indices_c=dados['diagnosis']==c
  #extraindo do DataFrame original as observacoes da
  #classec(obs_c sera um DataFrame tambem)
  obs_c=dados[indices_c]
  #extraindo a amostra da classe c
  #caso deseje-se realizar amostragem comreposicao
  #ou casolen(obs_c) < qtde_por_classe,pode-se
  #informar o parametro replace=True
  amostra_c=obs_c.sample(qtde_por_classe)
  #armazenando a amostra_c na lista de amostras
  amostras_por_classe.append(amostra_c)

#concatenando as amostras de cada classe em
#um único DataFrame
amostra_estratificada=pd.concat(amostras_por_classe)
amostra_estratificada
# Out:
#      sample_id  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 379    9013838        11.08         18.83           73.30      361.6
# 87    86135502        19.02         24.59          122.00     1076.0
# 12      846226        19.17         24.80          132.40     1123.0
# 45      857010        18.65         17.60          123.70     1076.0
# 563     926125        20.92         25.09          143.00     1347.0
# ..         ...          ...           ...             ...        ...
# 157    8711216        16.84         19.46          108.40      880.2
# 243   88411702        13.75         23.77           88.54      590.0
# 462    9113156        14.40         26.99           92.25      646.1
# 390   90317302        10.26         12.22           65.75      321.6
# 295     891923        13.77         13.27           88.06      582.7
#
#      mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 379          0.12160           0.21540         0.16890              0.06367
# 87           0.09029           0.12060         0.14680              0.08271
# 12           0.09740           0.24580         0.20650              0.11180
# 45           0.10990           0.16860         0.19740              0.10090
# 563          0.10990           0.22360         0.31740              0.14740
# ..               ...               ...             ...                  ...
# 157          0.07445           0.07223         0.05150              0.02771
# 243          0.08043           0.06807         0.04697              0.02344
# 462          0.06995           0.05223         0.03476              0.01737
# 390          0.09996           0.07542         0.01923              0.01968
# 295          0.09198           0.06221         0.01063              0.01917
#
#      mean_symmetry  ...  worst_texture  worst_perimeter  worst_area  \
# 379         0.2196  ...          32.82            91.76       508.1
# 87          0.1953  ...          30.41           152.90      1623.0
# 12          0.2397  ...          29.94           151.70      1332.0
# 45          0.1907  ...          21.32           150.60      1567.0
# 563         0.2149  ...          29.41           179.10      1819.0
# ..             ...  ...            ...              ...         ...
# 157         0.1844  ...          28.07           120.30      1032.0
# 243         0.1773  ...          26.34            98.00       706.0
# 462         0.1707  ...          31.98           100.40       734.6
# 390         0.1800  ...          15.65            73.23       394.5
# 295         0.1592  ...          16.93            94.17       661.1
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 379           0.21840             0.9379          0.84020
# 87            0.12490             0.3206          0.57550
# 12            0.10370             0.3903          0.36390
# 45            0.16790             0.5090          0.73450
# 563           0.14070             0.4186          0.65990
# ..                ...                ...              ...
# 157           0.08774             0.1710          0.18820
# 243           0.09368             0.1442          0.13590
# 462           0.10170             0.1460          0.14720
# 390           0.13430             0.1650          0.08615
# 295           0.11700             0.1072          0.03732
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension  diagnosis
# 379               0.25240          0.4154                  0.14030  malignant
# 87                0.19560          0.3956                  0.09288  malignant
# 12                0.17670          0.3176                  0.10230  malignant
# 45                0.23780          0.3799                  0.09185  malignant
# 563               0.25420          0.2929                  0.09873  malignant
# ..                    ...             ...                      ...        ...
# 157               0.08436          0.2527                  0.05972     benign
# 243               0.06106          0.2663                  0.06321     benign
# 462               0.05563          0.2345                  0.06464     benign
# 390               0.06696          0.2937                  0.07722     benign
# 295               0.05802          0.2823                  0.06794     benign
#
# [100 rows x 32 columns]

# %% [markdown]
# **Dados Ausentes**

# %%
import pandas as pd
